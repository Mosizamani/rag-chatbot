# %%
import os
print(os.getcwd())
# Out:
# /Users/mostafazamaniturk/Documents/USD/AAI-CapstoneProject/rag-chatbot

# %%
import os
print(os.path.exists('2018-Special-Inspection-Manual.pdf'))
# Out:
# False

# %%
import os
print(os.listdir())
# Out:
# ['.rocketride', '.gitignore', '.env', '.github', '.git', 'data', 'data.ipynb', 'my_rag_bot.pipe']

# %%
import os
import shutil

src = '2018-Special-Inspection-Manual.pdf'
dst = '/Users/mostafazamaniturk/Documents/USD/AAI-CapstoneProject/rag-chatbot/data'

if os.path.exists(src):
    shutil.copy(src, dst)
    print("File copied successfully!")
else:
    print(f"Error: The file does not exist at {os.path.abspath(src)}")
# Out:
# File copied successfully!

# %%
# For Markdown
with open('./data/my_notes.md', 'w') as f:
    f.write("# Project Overview\nThis is a sample markdown.")

# For PDFs (moving an existing file to the watched folder)
import shutil
src = '/Users/mostafazamaniturk/Documents/USD/AAI-CapstoneProject/rag-chatbot/2018-Special-Inspection-Manual.pdf'
dst = '/Users/mostafazamaniturk/Documents/USD/AAI-CapstoneProject/rag-chatbot/data'
shutil.copy(src, dst)
# Out:
# '/Users/mostafazamaniturk/Documents/USD/AAI-CapstoneProject/rag-chatbot/data/2018-Special-Inspection-Manual.pdf'

# %%
# %pip install rocketride
# Out:
# ...
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from rocketride import RocketClient

client = RocketClient(host="http://localhost:5565")

# Pushing text content directly from a cell variable
result = client.run("my_rag_bot.pipe", inputs={
    "content": "This is the text I want to embed from my notebook",
    "metadata": {"source": "jupyter_cell_01"}
})
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from rocketride import RocketClient
#       3 client = RocketClient(host="http://localhost:5565")
#       5 # Pushing text content directly from a cell variable
#
# ImportError: cannot import name 'RocketClient' from 'rocketride' (/Users/mostafazamaniturk/.venvs/py313/lib/python3.13/site-packages/rocketride/__init__.py)
